# %% [markdown]
# <a href="https://colab.research.google.com/github/TheRadDani/AI/blob/main/MobileNet_With_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()
# Out:
# ...
# 17235968/17225924 [==============================] - 0s 0us/step

# %%
def prepare_image(file):
    img_path = '/content/'
    img = image.load_img(img_path + file, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return tf.keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
from IPython.display import Image
Image(filename='/content/espectro.png', width=300,height=200)

# %%
preprocessed_image = prepare_image('lagartija.PNG')
predictions = mobile.predict(preprocessed_image)

# %%
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n01682714', 'American_chameleon', 0.83804566),
#   ('n01693334', 'green_lizard', 0.07842148),
#   ('n01687978', 'agama', 0.07330601),
#   ('n01689811', 'alligator_lizard', 0.005552752),
#   ('n01688243', 'frilled_lizard', 0.0023790887)]]

# %%
Image(filename='/content/luna.jpeg', width=300,height=200)

# %%
preprocessed_image = prepare_image('luna.jpeg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n02098286', 'West_Highland_white_terrier', 0.82560056),
#   ('n02113624', 'toy_poodle', 0.068037584),
#   ('n02095314', 'wire-haired_fox_terrier', 0.011811934),
#   ('n02085936', 'Maltese_dog', 0.011509121),
#   ('n02088364', 'beagle', 0.0064489925)]]

# %%
Image(filename='/content/buda.jpeg', width=300,height=300)

# %%
preprocessed_image = prepare_image('buda.jpeg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n04259630', 'sombrero', 0.6595704),
#   ('n07248320', 'book_jacket', 0.15591557),
#   ('n06596364', 'comic_book', 0.06806284),
#   ('n02699494', 'altar', 0.020499298),
#   ('n04209133', 'shower_cap', 0.011164956)]]
